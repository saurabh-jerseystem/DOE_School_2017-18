# %%
import os
import pandas as pd
import numpy as np

#df = pd.read_excel('narrative_raw.xlsx')
df = pd.read_csv('raw.csv',index_col = False, dtype = {"CountyCode": str,"DistrictCode": str,"SchoolCode": str})
df.head(2)
# Out:
#   CountyCode CountyName DistrictCode  DistrictName SchoolCode      SchoolName  \
# 0         01   ATLANTIC         0010  ABSECON CITY        050  EMMA C ATTALES
# 1         01   ATLANTIC         0010  ABSECON CITY        060  H ASHTON MARSH
#
#                                           Highlight1  \
# 0  Highly connected to our community through vari...
# 1  The H. Ashton Marsh Elementary School also ear...
#
#                                           Highlight2  \
# 0  Balanced literacy Language Arts curriculum sup...
# 1  H. Ashton Marsh School fosters 21st century le...
#
#                                           Highlight3  \
# 0  Professional Learning Communities improving ac...
# 1  The H.Ashton Marsh School is a recipient of th...
#
#                                              Mission  ...  \
# 0  Attales students will build character through ...  ...
# 1  The H. Ashton marsh Elementary School is commi...  ...
#
#                                               Health  \
# 0  All students participate in daily recess. Atta...
# 1  All students participate in daily recess. Mars...
#
#                                               Parent ClimateSurveyUsed  \
# 0  Our PTO is highly involved in supporting our s...               Yes
# 1  The H.A Marsh Elementary has a strong foundati...               Yes
#
#                                  WholsSurveyed  \
# 0  Students, Parents, Administrators, Teachers
# 1  Students, Parents, Administrators, Teachers
#
#                                     ClimateNarrative  \
# 0  As a means of addressing the needs identified ...
# 1  As a means of addressing the needs identified ...
#
#                                           Facilities  \
# 0  We recently renovated our media center to crea...
# 1  The H. Ashton Marsh Elementary School is a Pre...
#
#                                         SchoolSafety  \
# 0  January 1st our new lockdown system went live....
# 1  January 1st our new lockdown system went live....
#
#                                       TechnologySTEM  \
# 0  Students in our STEAM special meet once rotati...
# 1  The H. Ashton Marsh school offers a wide varie...
#
#                                       EarlyChildhood OtherInformation
# 0                                                NaN              NaN
# 1  The H. Ashton has three mixed delivery full da...              NaN
#
# [2 rows x 29 columns]

# %% [markdown]
# ### Check number of columns and rows

# %%
df.shape
# Out:
# (2519, 29)

# %% [markdown]
# ### Adding columns from 2016-17 table

# %%
df['Principal'] = 'NA'
df['SchoolAddress1'] = 'NA'
df['SchoolAddress2'] = 'NA'
df['SchoolCity'] = 'NA'
df['SchoolState'] = 'NA'
df['SchoolZip'] = 'NA'
df['SchoolPhone'] ='NA'
df['SchoolEmail'] = 'NA'
df['Website'] = 'NA'
df['Facebook'] ='NA'
df['Twitter'] ='NA'
df['Year'] = '2017-18'

# %% [markdown]
# ### Check if columns are added properly

# %%
df.head(2)
# Out:
#   CountyCode CountyName DistrictCode  DistrictName SchoolCode      SchoolName  \
# 0         01   ATLANTIC         0010  ABSECON CITY        050  EMMA C ATTALES
# 1         01   ATLANTIC         0010  ABSECON CITY        060  H ASHTON MARSH
#
#                                           Highlight1  \
# 0  Highly connected to our community through vari...
# 1  The H. Ashton Marsh Elementary School also ear...
#
#                                           Highlight2  \
# 0  Balanced literacy Language Arts curriculum sup...
# 1  H. Ashton Marsh School fosters 21st century le...
#
#                                           Highlight3  \
# 0  Professional Learning Communities improving ac...
# 1  The H.Ashton Marsh School is a recipient of th...
#
#                                              Mission  ... SchoolAddress2  \
# 0  Attales students will build character through ...  ...             NA
# 1  The H. Ashton marsh Elementary School is commi...  ...             NA
#
#   SchoolCity SchoolState SchoolZip SchoolPhone SchoolEmail Website Facebook  \
# 0         NA          NA        NA          NA          NA      NA       NA
# 1         NA          NA        NA          NA          NA      NA       NA
#
#   Twitter     Year
# 0      NA  2017-18
# 1      NA  2017-18
#
# [2 rows x 41 columns]

# %% [markdown]
# ### Check missing values

# %%
df.isnull().sum()
# Out:
# CountyCode              0
# CountyName              0
# DistrictCode            0
# DistrictName            0
# SchoolCode              0
# SchoolName              0
# Highlight1            263
# Highlight2            396
# Highlight3            555
# Mission               246
# Awards                658
# Courses               409
# Sports               1601
# SportsNarrative      1665
# Clubs                 504
# Programs              745
# Staff                 566
# Postsecondary        2084
# Supports              486
# Health                632
# Parent                411
# ClimateSurveyUsed    1437
# WholsSurveyed        1508
# ClimateNarrative     1509
# Facilities            825
# SchoolSafety         1363
# TechnologySTEM       1319
# EarlyChildhood       2024
# OtherInformation     1059
# Principal               0
# SchoolAddress1          0
# SchoolAddress2          0
# SchoolCity              0
# SchoolState             0
# SchoolZip               0
# SchoolPhone             0
# SchoolEmail             0
# Website                 0
# Facebook                0
# Twitter                 0
# Year                    0
# dtype: int64

# %% [markdown]
# ### Fill missing values

# %%
df = df.fillna('NA')

# %% [markdown]
# ### Check again if missing values are dealt properly

# %%
df.isnull().sum()
# Out:
# CountyCode           0
# CountyName           0
# DistrictCode         0
# DistrictName         0
# SchoolCode           0
# SchoolName           0
# Highlight1           0
# Highlight2           0
# Highlight3           0
# Mission              0
# Awards               0
# Courses              0
# Sports               0
# SportsNarrative      0
# Clubs                0
# Programs             0
# Staff                0
# Postsecondary        0
# Supports             0
# Health               0
# Parent               0
# ClimateSurveyUsed    0
# WholsSurveyed        0
# ClimateNarrative     0
# Facilities           0
# SchoolSafety         0
# TechnologySTEM       0
# EarlyChildhood       0
# OtherInformation     0
# Principal            0
# SchoolAddress1       0
# SchoolAddress2       0
# SchoolCity           0
# SchoolState          0
# SchoolZip            0
# SchoolPhone          0
# SchoolEmail          0
# Website              0
# Facebook             0
# Twitter              0
# Year                 0
# dtype: int64

# %% [markdown]
# ### Check for meaningless values such as '**','N'

# %%
#df['CompSupport_Grad67'] = df['CompSupport_Grad67'].replace('**',9999999)

#df['PercentDaysPresent'] = df['PercentDaysPresent'].replace('N',9999999)

# %% [markdown]
# ### Check Data types of all columns

# %%
df.dtypes
# Out:
# CountyCode           object
# CountyName           object
# DistrictCode         object
# DistrictName         object
# SchoolCode           object
# SchoolName           object
# Highlight1           object
# Highlight2           object
# Highlight3           object
# Mission              object
# Awards               object
# Courses              object
# Sports               object
# SportsNarrative      object
# Clubs                object
# Programs             object
# Staff                object
# Postsecondary        object
# Supports             object
# Health               object
# Parent               object
# ClimateSurveyUsed    object
# WholsSurveyed        object
# ClimateNarrative     object
# Facilities           object
# SchoolSafety         object
# TechnologySTEM       object
# EarlyChildhood       object
# OtherInformation     object
# Principal            object
# SchoolAddress1       object
# SchoolAddress2       object
# SchoolCity           object
# SchoolState          object
# SchoolZip            object
# SchoolPhone          object
# SchoolEmail          object
# Website              object
# Facebook             object
# Twitter              object
# Year                 object
# dtype: object

# %% [markdown]
# ### Change Data types

# %%
#df["PercentDaysPresent"] = df["PercentDaysPresent"].astype(float)
#df["CutOffScoreTargetedSupImp"] = df["CutOffScoreTargetedSupImp"].astype(float)

# %% [markdown]
# ### Check the changed data types

# %%
#df.dtypes

# %% [markdown]
# ### Get a look at final data

# %%
df.head()
# Out:
#   CountyCode CountyName DistrictCode   DistrictName SchoolCode  \
# 0         01   ATLANTIC         0010   ABSECON CITY        050
# 1         01   ATLANTIC         0010   ABSECON CITY        060
# 2         01   ATLANTIC         0110  ATLANTIC CITY        010
# 3         01   ATLANTIC         0110  ATLANTIC CITY        030
# 4         01   ATLANTIC         0110  ATLANTIC CITY        050
#
#                   SchoolName  \
# 0             EMMA C ATTALES
# 1             H ASHTON MARSH
# 2  ATLANTIC CITY HIGH SCHOOL
# 3    SOVEREIGN AVENUE SCHOOL
# 4     CHELSEA HEIGHTS SCHOOL
#
#                                           Highlight1  \
# 0  Highly connected to our community through vari...
# 1  The H. Ashton Marsh Elementary School also ear...
# 2  Atlantic City High School has partnerships and...
# 3  NJ Benchmark School for two consecutive years;...
# 4  Students may participate in Sportmanship Club,...
#
#                                           Highlight2  \
# 0  Balanced literacy Language Arts curriculum sup...
# 1  H. Ashton Marsh School fosters 21st century le...
# 2  Atlantic City High School offers 19 Advanced P...
# 3  Orchestral Academy School, Asian & Latino Club...
# 4  Teachers were awarded grant money, which suppl...
#
#                                           Highlight3  \
# 0  Professional Learning Communities improving ac...
# 1  The H.Ashton Marsh School is a recipient of th...
# 2  Navy ROTC Unit awarded the Distinguished Unit ...
# 3  Jr. National Honor Society; Chorus, Yoga, TV p...
# 4  Academic contests, such as Spelling Bee, Orato...
#
#                                              Mission  ... SchoolAddress2  \
# 0  Attales students will build character through ...  ...             NA
# 1  The H. Ashton marsh Elementary School is commi...  ...             NA
# 2  The Mission of Atlantic City High School is to...  ...             NA
# 3  Sovereign Avenue School is a professional lear...  ...             NA
# 4  Chelsea Heights School is committed to providi...  ...             NA
#
#   SchoolCity SchoolState SchoolZip SchoolPhone SchoolEmail Website Facebook  \
# 0         NA          NA        NA          NA          NA      NA       NA
# 1         NA          NA        NA          NA          NA      NA       NA
# 2         NA          NA        NA          NA          NA      NA       NA
# 3         NA          NA        NA          NA          NA      NA       NA
# 4         NA          NA        NA          NA          NA      NA       NA
#
#   Twitter     Year
# 0      NA  2017-18
# 1      NA  2017-18
# 2      NA  2017-18
# 3      NA  2017-18
# 4      NA  2017-18
#
# [5 rows x 41 columns]

# %%
#df1.to_csv(df1.csv)
df.to_csv('Narrative.csv', encoding='utf-8', index=False)

# %%
#x= df1.to_excel('output1.xlsx')  # doctest: +SKIP
